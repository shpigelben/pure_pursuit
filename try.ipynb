# %%
import numpy as np
A = np.array([1/np.sqrt(2), -1/np.sqrt(2)])
np.rad2deg(np.arctan(A[1]/A[0]))
# Out:
# np.float64(-45.0)

# %%
from a_evador import Pursuer, Evader

p1 = Pursuer([0.0,0.0], [1.0,0.0])
print(p1.position)
p1.move(1.0)
print(p1.position)
# Out:
# [0. 0.]
# [1. 0.]

# %%
p1.move(1.0)
print(p1.position)
# Out:
# [4. 0.]

# %%
import matplotlib.pyplot as plt
plt.plot([[1,2],[2,3]])

# %%
# Out:
# [1, 2, 1, 2]
